# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r'IPL_BallByBall2008_2024.csv')
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_34408\2719549974.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv(r'IPL_BallByBall2008_2024.csv')

# %%
df1[df1.isnull()].size
# Out:
# 4859421

# %%
df1['wicket_type'].sample(12)
# Out:
# 94709        NaN
# 225256       NaN
# 171810       NaN
# 90127        lbw
# 206705       NaN
# 122662       NaN
# 174085       NaN
# 92841        NaN
# 44109        NaN
# 211131    caught
# 4552         NaN
# 109984       NaN
# Name: wicket_type, dtype: object

# %%
df1[df1['wicket_type']=='caught']
# Out:
#         Match id        Date   Season           Batting team  \
# 0         335982  2008-04-18  2007/08  Kolkata Knight Riders
# 1         335982  2008-04-18  2007/08  Kolkata Knight Riders
# 2         335982  2008-04-18  2007/08  Kolkata Knight Riders
# 3         335982  2008-04-18  2007/08  Kolkata Knight Riders
# 4         335982  2008-04-18  2007/08  Kolkata Knight Riders
# ...          ...         ...      ...                    ...
# 255754   1426287  2024-05-01     2024           Punjab Kings
# 255755   1426287  2024-05-01     2024           Punjab Kings
# 255756   1426287  2024-05-01     2024           Punjab Kings
# 255757   1426287  2024-05-01     2024           Punjab Kings
# 255758   1426287  2024-05-01     2024           Punjab Kings
#
#                        Bowling team  Innings No  Ball No      Bowler  \
# 0       Royal Challengers Bangalore           1      0.1     P Kumar
# 1       Royal Challengers Bangalore           1      0.2     P Kumar
# ...

# %%
df1.tail(4)
# Out:
#         Match id        Date Season  Batting team         Bowling team  \
# 255755   1426287  2024-05-01   2024  Punjab Kings  Chennai Super Kings
# 255756   1426287  2024-05-01   2024  Punjab Kings  Chennai Super Kings
# 255757   1426287  2024-05-01   2024  Punjab Kings  Chennai Super Kings
# 255758   1426287  2024-05-01   2024  Punjab Kings  Chennai Super Kings
#
#         Innings No  Ball No      Bowler         Striker     Non Striker  \
# 255755           2     17.2  RJ Gleeson       SM Curran  Shashank Singh
# 255756           2     17.3  RJ Gleeson       SM Curran  Shashank Singh
# 255757           2     17.4  RJ Gleeson       SM Curran  Shashank Singh
# 255758           2     17.5  RJ Gleeson  Shashank Singh       SM Curran
#
#         runs_scored  extras type of extras  score score/wicket  \
# 255755            4       0            NaN    160        160/3
# 255756            0       0            NaN    160        160/3
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255759 entries, 0 to 255758
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Match id             255759 non-null  int64
#  1   Date                 255759 non-null  object
#  2   Season               255759 non-null  object
#  3   Batting team         255759 non-null  object
#  4   Bowling team         255759 non-null  object
#  5   Innings No           255759 non-null  int64
#  6   Ball No              255759 non-null  float64
#  7   Bowler               255759 non-null  object
#  8   Striker              255759 non-null  object
#  9   Non Striker          255759 non-null  object
#  10  runs_scored          255759 non-null  int64
#  11  extras               255759 non-null  int64
#  12  type of extras       13823 non-null   object
#  13  score                255759 non-null  int64
#  14  score/wicket         255759 non-null  object
# ...

# %%
df1.size
# Out:
# 4859421
